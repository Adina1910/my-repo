# %%
from collections import deque

# Create an empty graph (dictionary)
graph = {}

# Take user input for number of nodes
n = int(input("Enter number of nodes: "))

# Take input for graph connections
for i in range(n):
    node = input(f"Enter node name {i+1}: ")
    neighbors = input(f"Enter neighbors of {node} (separated by space): ").split()
    graph[node] = neighbors

# Take starting node
start = input("Enter starting node for BFS: ")

# BFS algorithm
visited = []
queue = deque([start])

print("\nBFS Traversal:")

while queue:
    node = queue.popleft()
    if node not in visited:
        print(node, end=" ")
        visited.append(node)
        for neighbor in graph[node]:
            if neighbor not in visited:
                queue.append(neighbor)
# Out:
# Enter number of nodes:  7
# Enter node name 1:  A
# Enter neighbors of A (separated by space):  B C D
# Enter node name 2:  B
# Enter neighbors of B (separated by space):  E
# Enter node name 3:  C
# Enter neighbors of C (separated by space):  F
# Enter node name 4:  D
# Enter neighbors of D (separated by space):  G
# Enter node name 5:  E
# Enter neighbors of E (separated by space):
# Enter node name 6:  F
# Enter neighbors of F (separated by space):
# Enter node name 7:  G
# Enter neighbors of G (separated by space):
# Enter starting node for BFS:  A
# BFS Traversal:
# A B C D E F G
